# %%
# Importing our modules, packages, and libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Series
#
# Two important data types defined by pandas are ``Series`` and ``DataFrames``.
#
# You can think of a ``Series`` as a "column" of data, suich as a collection of observations on a single variable.
#
# A DataFrame is an object for storing related columns of data.
#
# But Series provide more than NumPy arrays. Not only do they have some additional (statistically oriented methods).
#
# Documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html

# %%
# Initializing a series - input a list and you can assign a name
s = pd.Series(np.random.randn(4), name="champion winrates")
s
# Out:
# 0   -0.837669
# 1   -0.770415
# 2    1.161852
# 3   -0.517420
# Name: champion winrates, dtype: float64

# %%
# Manipulations to data
print(s * 100)
print(np.abs(s))
# Out:
# 0    -83.766921
# 1    -77.041486
# 2    116.185169
# 3    -51.742047
# Name: champion winrates, dtype: float64
# 0    0.837669
# 1    0.770415
# 2    1.161852
# 3    0.517420
# Name: champion winrates, dtype: float64

# %%
s.describe() # Describes statistical data
# Out:
# count    4.000000
# mean    -0.240913
# std      0.945286
# min     -0.837669
# 25%     -0.787228
# 50%     -0.643918
# 75%     -0.097602
# max      1.161852
# Name: champion winrates, dtype: float64

# %%
# Renaming row values
s.index = ['AMIN', 'KAYNE', 'Hello', 'YES']
s
# Out:
# AMIN    -0.837669
# KAYNE   -0.770415
# Hello    1.161852
# YES     -0.517420
# Name: champion winrates, dtype: float64

# %%
# Finding values from index, similar to key value pairing in dictionary
s['AMIN'] = 1
s['AMIN']
# Out:
# 1.0

# %% [markdown]
# # DataFrames
# While a ``Series`` is a single column of data, a ``DataFrame`` is a combination of columns, one for each variable.
#
# A ``DataFrame`` in pandas is pretty similar to an Excel spreadsheet with lots of functionality.
#
# It is a powerful tool for representing and analyzing data organized into rows and columns.

# %%
covid_df = pd.read_csv('./usa_county_wise.csv') # Read excel sheet to a dataFrame (JSON, tables, etc.)
type(covid_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Viewing Data in DataFrame

# %%
covid_df.head() # Looking at the dataFrame
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_                  Combined_Key     Date  Confirmed  Deaths
# 0 -14.2710 -170.1320            American Samoa, US  1/22/20          0       0
# 1  13.4443  144.7937                      Guam, US  1/22/20          0       0
# 2  15.0979  145.6739  Northern Mariana Islands, US  1/22/20          0       0
# 3  18.2208  -66.5901               Puerto Rico, US  1/22/20          0       0
# 4  18.3358  -64.8963            Virgin Islands, US  1/22/20          0       0

# %%
covid_df.describe() # Describes statistical data for all columns
# Out:
#                 UID          code3           FIPS            Lat  \
# count  2.374690e+05  237469.000000  237323.000000  237469.000000
# mean   8.390300e+07     839.444205   32090.929560      37.183790
# std    3.291996e+06      18.088416   17822.449027       8.621715
# min    1.600000e+01      16.000000      60.000000     -14.271000
# 25%    8.401904e+07     840.000000   19037.000000      34.237321
# 50%    8.403005e+07     840.000000   30045.000000      38.147359
# 75%    8.404701e+07     840.000000   47011.000000      41.684463
# max    8.410000e+07     850.000000   99999.000000      69.314792
#
#                Long_      Confirmed         Deaths
# count  237469.000000  237469.000000  237469.000000
# mean      -89.174224       7.659294       0.151691
# std        21.435390     279.813276       6.906155
# min      -170.132000       0.000000       0.000000
# 25%       -98.037489       0.000000       0.000000
# 50%       -89.825123       0.000000       0.000000
# 75%       -82.793570       0.000000       0.000000
# max       145.673900   57159.000000    1584.000000

# %% [markdown]
# ### Finding columns with all rows or all rows with some columns

# %%
covid_df[2:5] # Choose specific rows
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_                  Combined_Key     Date  Confirmed  Deaths
# 2  15.0979  145.6739  Northern Mariana Islands, US  1/22/20          0       0
# 3  18.2208  -66.5901               Puerto Rico, US  1/22/20          0       0
# 4  18.3358  -64.8963            Virgin Islands, US  1/22/20          0       0

# %%
covid_df[['UID', 'iso2']] # Choose specific columns to look at through list
# Out:
#              UID iso2
# 0             16   AS
# 1            316   GU
# 2            580   MP
# 3            630   PR
# 4            850   VI
# ...          ...  ...
# 237464  84090053   US
# 237465  84090054   US
# 237466  84090055   US
# 237467  84090056   US
# 237468  84099999   US
#
# [237469 rows x 2 columns]

# %% [markdown]
# ### Finding Specific Columns and Specific Rows

# %%
covid_df.iloc[2:5, 0:4] # iloc uses the indices not the names
# Out:
#    UID iso2 iso3  code3
# 2  580   MP  MNP    580
# 3  630   PR  PRI    630
# 4  850   VI  VIR    850

# %%
covid_df.loc[covid_df.index[2:5], ['UID', 'iso2', 'iso3', 'code3']] # use namings to find rows & columns
# Out:
#    UID iso2 iso3  code3
# 2  580   MP  MNP    580
# 3  630   PR  PRI    630
# 4  850   VI  VIR    850

# %%
covid_df[covid_df['Lat']<18] # Find certain values satisfying a condition
# Out:
#              UID iso2 iso3  code3     FIPS      Admin2  \
# 0             16   AS  ASM     16     60.0         NaN
# 1            316   GU  GUM    316     66.0         NaN
# 2            580   MP  MNP    580     69.0         NaN
# 3149    84080001   US  USA    840  80001.0   Out of AL
# 3150    84080002   US  USA    840  80002.0   Out of AK
# ...          ...  ...  ...    ...      ...         ...
# 237464  84090053   US  USA    840  90053.0  Unassigned
# 237465  84090054   US  USA    840  90054.0  Unassigned
# 237466  84090055   US  USA    840  90055.0  Unassigned
# 237467  84090056   US  USA    840  90056.0  Unassigned
# 237468  84099999   US  USA    840  99999.0         NaN
#
#                   Province_State Country_Region      Lat     Long_  \
# 0                 American Samoa             US -14.2710 -170.1320
# 1                           Guam             US  13.4443  144.7937
# 2       Northern Mariana Islands             US  15.0979  145.6739
# 3149                     Alabama             US   0.0000    0.0000
# 3150                      Alaska             US   0.0000    0.0000
# ...                          ...            ...      ...       ...
# 237464                Washington             US   0.0000    0.0000
# 237465             West Virginia             US   0.0000    0.0000
# 237466                 Wisconsin             US   0.0000    0.0000
# 237467                   Wyoming             US   0.0000    0.0000
# 237468            Grand Princess             US   0.0000    0.0000
#
#                          Combined_Key     Date  Confirmed  Deaths
# 0                  American Samoa, US  1/22/20          0       0
# 1                            Guam, US  1/22/20          0       0
# 2        Northern Mariana Islands, US  1/22/20          0       0
# 3149           Out of AL, Alabama, US  1/22/20          0       0
# 3150            Out of AK, Alaska, US  1/22/20          0       0
# ...                               ...      ...        ...     ...
# 237464     Unassigned, Washington, US   4/3/20        501       0
# 237465  Unassigned, West Virginia, US   4/3/20          0       0
# 237466      Unassigned, Wisconsin, US   4/3/20          0       4
# 237467        Unassigned, Wyoming, US   4/3/20          0       0
# 237468             Grand Princess, US   4/3/20        103       3
#
# [7811 rows x 14 columns]

# %%
covid_df_copy = covid_df.set_index('code3') # Setting a value as the index

covid_df_copy.iloc[1:3]

# %% [markdown]
# ## Changing values

# %%
# Out:
#        UID iso2 iso3  FIPS Admin2            Province_State Country_Region  \
# code3
# 316    316   GU  GUM  66.0    NaN                      Guam             US
# 580    580   MP  MNP  69.0    NaN  Northern Mariana Islands             US
#
#            Lat     Long_                  Combined_Key     Date  Confirmed  \
# code3
# 316    13.4443  144.7937                      Guam, US  1/22/20          0
# 580    15.0979  145.6739  Northern Mariana Islands, US  1/22/20          0
#
#        Deaths
# code3
# 316         0
# 580         0

# %%
covid_df[['UID']][0:2]
# Out:
#    UID
# 0   16
# 1  316

# %%
covid_df['UID'] *= 1e3 # Changing value
covid_df[['UID']][0:2]
# Out:
#            UID
# 0   16000000.0
# 1  316000000.0

# %%
covid_df[1:10]
# Out:
#             UID iso2 iso3  code3    FIPS   Admin2            Province_State  \
# 1  3.160000e+08   GU  GUM    316    66.0      NaN                      Guam
# 2  5.800000e+08   MP  MNP    580    69.0      NaN  Northern Mariana Islands
# 3  6.300000e+08   PR  PRI    630    72.0      NaN               Puerto Rico
# 4  8.500000e+08   VI  VIR    850    78.0      NaN            Virgin Islands
# 5  8.400100e+13   US  USA    840  1001.0  Autauga                   Alabama
# 6  8.400100e+13   US  USA    840  1003.0  Baldwin                   Alabama
# 7  8.400100e+13   US  USA    840  1005.0  Barbour                   Alabama
# 8  8.400101e+13   US  USA    840  1007.0     Bibb                   Alabama
# 9  8.400101e+13   US  USA    840  1009.0   Blount                   Alabama
#
#   Country_Region        Lat       Long_                  Combined_Key  \
# 1             US  13.444300  144.793700                      Guam, US
# 2             US  15.097900  145.673900  Northern Mariana Islands, US
# 3             US  18.220800  -66.590100               Puerto Rico, US
# 4             US  18.335800  -64.896300            Virgin Islands, US
# 5             US  32.539527  -86.644082          Autauga, Alabama, US
# 6             US  30.727750  -87.722071          Baldwin, Alabama, US
# 7             US  31.868263  -85.387129          Barbour, Alabama, US
# 8             US  32.996421  -87.125115             Bibb, Alabama, US
# 9             US  33.982109  -86.567906           Blount, Alabama, US
#
#       Date  Confirmed  Deaths
# 1  1/22/20          0       0
# 2  1/22/20          0       0
# 3  1/22/20          0       0
# 4  1/22/20          0       0
# 5  1/22/20          0       0
# 6  1/22/20          0       0
# 7  1/22/20          0       0
# 8  1/22/20          0       0
# 9  1/22/20          0       0

# %%
covid_df['code4'] = covid_df['code3'] * 1e4 # Adding in new column
covid_df[1:10]
# Out:
#             UID iso2 iso3  code3    FIPS   Admin2            Province_State  \
# 1  3.160000e+08   GU  GUM    316    66.0      NaN                      Guam
# 2  5.800000e+08   MP  MNP    580    69.0      NaN  Northern Mariana Islands
# 3  6.300000e+08   PR  PRI    630    72.0      NaN               Puerto Rico
# 4  8.500000e+08   VI  VIR    850    78.0      NaN            Virgin Islands
# 5  8.400100e+13   US  USA    840  1001.0  Autauga                   Alabama
# 6  8.400100e+13   US  USA    840  1003.0  Baldwin                   Alabama
# 7  8.400100e+13   US  USA    840  1005.0  Barbour                   Alabama
# 8  8.400101e+13   US  USA    840  1007.0     Bibb                   Alabama
# 9  8.400101e+13   US  USA    840  1009.0   Blount                   Alabama
#
#   Country_Region        Lat       Long_                  Combined_Key  \
# 1             US  13.444300  144.793700                      Guam, US
# 2             US  15.097900  145.673900  Northern Mariana Islands, US
# 3             US  18.220800  -66.590100               Puerto Rico, US
# 4             US  18.335800  -64.896300            Virgin Islands, US
# 5             US  32.539527  -86.644082          Autauga, Alabama, US
# 6             US  30.727750  -87.722071          Baldwin, Alabama, US
# 7             US  31.868263  -85.387129          Barbour, Alabama, US
# 8             US  32.996421  -87.125115             Bibb, Alabama, US
# 9             US  33.982109  -86.567906           Blount, Alabama, US
#
#       Date  Confirmed  Deaths      code4
# 1  1/22/20          0       0  3160000.0
# 2  1/22/20          0       0  5800000.0
# 3  1/22/20          0       0  6300000.0
# 4  1/22/20          0       0  8500000.0
# 5  1/22/20          0       0  8400000.0
# 6  1/22/20          0       0  8400000.0
# 7  1/22/20          0       0  8400000.0
# 8  1/22/20          0       0  8400000.0
# 9  1/22/20          0       0  8400000.0

# %% [markdown]
# ### Sorting Data

# %%
covid_df = covid_df.sort_values(by='Lat', ascending=False) # Sorting values to be in a specific way
covid_df[1:10]
# Out:
#                  UID iso2 iso3  code3    FIPS       Admin2 Province_State  \
# 52138   8.400218e+13   US  USA    840  2185.0  North Slope         Alaska
# 91174   8.400218e+13   US  USA    840  2185.0  North Slope         Alaska
# 32620   8.400218e+13   US  USA    840  2185.0  North Slope         Alaska
# 188764  8.400218e+13   US  USA    840  2185.0  North Slope         Alaska
# 110692  8.400218e+13   US  USA    840  2185.0  North Slope         Alaska
# 185511  8.400218e+13   US  USA    840  2185.0  North Slope         Alaska
# 42379   8.400218e+13   US  USA    840  2185.0  North Slope         Alaska
# 104186  8.400218e+13   US  USA    840  2185.0  North Slope         Alaska
# 214788  8.400218e+13   US  USA    840  2185.0  North Slope         Alaska
#
#        Country_Region        Lat       Long_             Combined_Key  \
# 52138              US  69.314792 -153.483609  North Slope, Alaska, US
# 91174              US  69.314792 -153.483609  North Slope, Alaska, US
# 32620              US  69.314792 -153.483609  North Slope, Alaska, US
# 188764             US  69.314792 -153.483609  North Slope, Alaska, US
# 110692             US  69.314792 -153.483609  North Slope, Alaska, US
# 185511             US  69.314792 -153.483609  North Slope, Alaska, US
# 42379              US  69.314792 -153.483609  North Slope, Alaska, US
# 104186             US  69.314792 -153.483609  North Slope, Alaska, US
# 214788             US  69.314792 -153.483609  North Slope, Alaska, US
#
#            Date  Confirmed  Deaths      code4
# 52138    2/7/20          0       0  8400000.0
# 91174   2/19/20          0       0  8400000.0
# 32620    2/1/20          0       0  8400000.0
# 188764  3/20/20          0       0  8400000.0
# 110692  2/25/20          0       0  8400000.0
# 185511  3/19/20          0       0  8400000.0
# 42379    2/4/20          0       0  8400000.0
# 104186  2/23/20          0       0  8400000.0
# 214788  3/28/20          0       0  8400000.0

# %% [markdown]
# ### Parsing through values

# %%
covid_df.isnull()[1:10] # Data is flawed sometimes - see if it is null

# %%
covid_df.isnull().sum() # see how many null values there are

# %%
covid_df.groupby(['Province_State']).mean() # Group by to see similarity based on categorical variables

# %%
# Grouping by both province_state and combined_key for mean
covid_df.groupby(['Province_State', 'Combined_Key']).mean()

# %%
# Combining choosing data and grouping it
covid_df[covid_df['age']<18].groupby(['sex', 'pclass']).mean()  # Combining methods together

# %% [markdown]
# ### Graphing

# %%
pd.value_counts(covid_df['Province_State']).plot.bar() # counts of certain and build graph of it
